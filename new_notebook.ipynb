# %%
# %load_ext autoreload
# %autoreload 2

# %%
print('dadasd')
# Out:
# dadasd

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pip install -r requirements.txt
# Out:
# Collecting mlflow==2.7.1
#   Downloading mlflow-2.7.1-py3-none-any.whl (18.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 37.1 MB/s eta 0:00:0000:0100:01
# Collecting jupyterlab==4.0.7
#   Downloading jupyterlab-4.0.7-py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 46.2 MB/s eta 0:00:0000:0100:01
# Collecting psycopg==3.1.12
#   Downloading psycopg-3.1.12-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 KB 3.1 MB/s eta 0:00:00a 0:00:01
# Collecting psycopg[binary,pool]
#   Downloading psycopg-3.2.5-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.7/198.7 KB 12.4 MB/s eta 0:00:00
# Collecting pandas==2.0.1
#   Downloading pandas-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 42.5 MB/s eta 0:00:0000:0100:01
# Collecting scikit-learn==1.3.1
#   Downloading scikit_learn-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 46.1 MB/s eta 0:00:0000:010:01m
# Requirement already satisfied: catboost==1.2.2 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.2.2)
# Collecting scipy==1.11.3
#   Downloading scipy-1.11.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 34.4 MB/s eta 0:00:0000:0100:01
# Collecting optuna==3.4.0
#   Downloading optuna-3.4.0-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 KB 49.6 MB/s eta 0:00:00
# Collecting ipywidgets==8.1.1
#   Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 KB 4.4 MB/s eta 0:00:00
# Collecting seaborn==0.13.0
#   Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 KB 37.2 MB/s eta 0:00:00
# Collecting autofeat==2.1.2
#   Downloading autofeat-2.1.2-py3-none-any.whl (25 kB)
# Collecting mlxtend==0.23.0
#   Downloading mlxtend-0.23.0-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 67.0 MB/s eta 0:00:00
# Collecting plotly==5.20.0
#   Downloading plotly-5.20.0-py3-none-any.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 48.4 MB/s eta 0:00:0000:0100:01
# Collecting kaleido==0.2.1
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 4.8 MB/s eta 0:00:00:00:0100:01
# Collecting boto3==1.34.77
#   Downloading boto3-1.34.77-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 KB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: markdown<4,>=3.3 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (3.7)
# Collecting querystring-parser<2
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (1.15.1)
# Collecting protobuf<5,>=3.12.0
#   Downloading protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 KB 6.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: entrypoints<1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (0.4)
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 KB 16.7 MB/s eta 0:00:00
# Collecting pyarrow<14,>=4.0.0
#   Downloading pyarrow-13.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 MB 17.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib<4 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (3.8.2)
# Requirement already satisfied: pytz<2024 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (2023.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (3.1.41)
# Requirement already satisfied: click<9,>=7.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (8.1.7)
# Collecting Flask<3
#   Downloading flask-2.3.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 KB 2.3 MB/s eta 0:00:00ta 0:00:01
# Collecting gunicorn<22
#   Using cached gunicorn-21.2.0-py3-none-any.whl (80 kB)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (2.0.25)
# Collecting cloudpickle<3
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: packaging<24 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: Jinja2<4,>=2.11 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (3.1.6)
# Collecting importlib-metadata!=4.7.0,<7,>=3.7.0
#   Using cached importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy<2 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from mlflow==2.7.1->-r requirements.txt (line 1)) (1.26.3)
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 KB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.2.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from jupyterlab==4.0.7->-r requirements.txt (line 2)) (6.4.2)
# Collecting jupyterlab-server<3,>=2.19.0
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 KB 1.4 MB/s eta 0:00:00ta 0:00:01
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 KB 2.4 MB/s eta 0:00:00
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: traitlets in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from jupyterlab==4.0.7->-r requirements.txt (line 2)) (5.14.3)
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 KB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from jupyterlab==4.0.7->-r requirements.txt (line 2)) (5.7.2)
# Collecting notebook-shim>=0.2
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: ipykernel in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from jupyterlab==4.0.7->-r requirements.txt (line 2)) (6.29.5)
# Collecting tomli
#   Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=4.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from psycopg==3.1.12->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from pandas==2.0.1->-r requirements.txt (line 5)) (2023.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from pandas==2.0.1->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from scikit-learn==1.3.1->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from scikit-learn==1.3.1->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: graphviz in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from catboost==1.2.2->-r requirements.txt (line 7)) (0.20.1)
# Requirement already satisfied: six in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from catboost==1.2.2->-r requirements.txt (line 7)) (1.16.0)
# Collecting colorlog
#   Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from optuna==3.4.0->-r requirements.txt (line 9)) (4.66.1)
# Collecting jupyterlab-widgets~=3.0.9
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 KB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: comm>=0.1.3 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipywidgets==8.1.1->-r requirements.txt (line 10)) (0.2.2)
# Collecting widgetsnbextension~=4.0.9
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 45.0 MB/s eta 0:00:00:00:01
# Requirement already satisfied: ipython>=6.1.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipywidgets==8.1.1->-r requirements.txt (line 10)) (8.32.0)
# Collecting pint<1.0,>=0.17
#   Downloading Pint-0.24.4-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 KB 3.4 MB/s eta 0:00:0000:01
# Collecting sympy<2.0.0,>=1.7.1
#   Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 51.6 MB/s eta 0:00:0000:01:00:01
# Collecting numba>=0.53.1
#   Downloading numba-0.61.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 19.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tenacity>=6.2.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from plotly==5.20.0->-r requirements.txt (line 14)) (8.2.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from boto3==1.34.77->-r requirements.txt (line 16)) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from boto3==1.34.77->-r requirements.txt (line 16)) (0.10.0)
# Collecting botocore<1.35.0,>=1.34.77
#   Downloading botocore-1.34.162-py3-none-any.whl (12.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 50.7 MB/s eta 0:00:0000:0100:01
# Collecting psycopg[binary,pool]
#   Downloading psycopg-3.2.4-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.7/198.7 KB 3.5 MB/s eta 0:00:0000:01
#   Downloading psycopg-3.2.3-py3-none-any.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.9/197.9 KB 10.0 MB/s eta 0:00:00
#   Downloading psycopg-3.2.2-py3-none-any.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.9/197.9 KB 1.5 MB/s eta 0:00:0000:01
#   Downloading psycopg-3.2.1-py3-none-any.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 KB 5.9 MB/s eta 0:00:00
#   Downloading psycopg-3.2.0-py3-none-any.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 KB 10.9 MB/s eta 0:00:00
#   Downloading psycopg-3.1.20-py3-none-any.whl (179 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.5/179.5 KB 9.3 MB/s eta 0:00:00
#   Downloading psycopg-3.1.19-py3-none-any.whl (179 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.4/179.4 KB 11.4 MB/s eta 0:00:00
#   Downloading psycopg-3.1.18-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.1/178.1 KB 5.6 MB/s eta 0:00:00
#   Downloading psycopg-3.1.17-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 KB 16.1 MB/s eta 0:00:00
#   Downloading psycopg-3.1.16-py3-none-any.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 KB 7.5 MB/s eta 0:00:00
#   Downloading psycopg-3.1.15-py3-none-any.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 KB 10.2 MB/s eta 0:00:00
#   Downloading psycopg-3.1.14-py3-none-any.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 KB 6.4 MB/s eta 0:00:00
#   Downloading psycopg-3.1.13-py3-none-any.whl (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.0/173.0 KB 2.4 MB/s eta 0:00:00a 0:00:01
# Collecting psycopg-binary==3.1.12
#   Downloading psycopg_binary-3.1.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 32.1 MB/s eta 0:00:0000:01:00:01
# Collecting psycopg-pool
#   Downloading psycopg_pool-3.2.6-py3-none-any.whl (38 kB)
# Requirement already satisfied: Mako in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==2.7.1->-r requirements.txt (line 1)) (1.3.9)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from botocore<1.35.0,>=1.34.77->boto3==1.34.77->-r requirements.txt (line 16)) (2.0.7)
# Collecting pyjwt>=1.7.0
#   Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Collecting oauthlib>=3.1.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 KB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: tabulate>=0.7.7 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.7.1->-r requirements.txt (line 1)) (0.9.0)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: blinker>=1.6.2 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from Flask<3->mlflow==2.7.1->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from Flask<3->mlflow==2.7.1->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: Werkzeug>=2.3.7 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from Flask<3->mlflow==2.7.1->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from gitpython<4,>=2.1.0->mlflow==2.7.1->-r requirements.txt (line 1)) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.7.1->-r requirements.txt (line 1)) (3.21.0)
# Requirement already satisfied: pexpect>4.3 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (2.17.2)
# Requirement already satisfied: matplotlib-inline in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (0.1.7)
# Requirement already satisfied: jedi>=0.16 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (0.19.2)
# Requirement already satisfied: stack_data in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (1.2.2)
# Requirement already satisfied: decorator in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (5.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow==2.7.1->-r requirements.txt (line 1)) (3.0.2)
# Collecting anyio>=3.1.0
#   Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 KB 2.2 MB/s eta 0:00:00ta 0:00:01
# Collecting jupyter-events>=0.11.0
#   Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 KB 6.5 MB/s eta 0:00:0000:01
# Collecting nbformat>=5.3.0
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 2.6 MB/s eta 0:00:00
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting prometheus-client>=0.9
#   Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 KB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.7->-r requirements.txt (line 2)) (8.6.3)
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: pyzmq>=24 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.0.7->-r requirements.txt (line 2)) (26.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from jupyter-core->jupyterlab==4.0.7->-r requirements.txt (line 2)) (3.11.0)
# Collecting babel>=2.10
#   Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 58.0 MB/s eta 0:00:0000:010:01m
# Collecting jsonschema>=4.18.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 KB 5.4 MB/s eta 0:00:00
# Collecting json5>=0.9.0
#   Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: cycler>=0.10 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.7.1->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.7.1->-r requirements.txt (line 1)) (4.47.2)
# Requirement already satisfied: pillow>=8 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.7.1->-r requirements.txt (line 1)) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.7.1->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.7.1->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.7.1->-r requirements.txt (line 1)) (1.4.5)
# Collecting llvmlite<0.45,>=0.44.0dev0
#   Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 24.2 MB/s eta 0:00:0000:0100:01
# Collecting flexcache>=0.3
#   Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Collecting flexparser>=0.4
#   Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.7.1->-r requirements.txt (line 1)) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.7.1->-r requirements.txt (line 1)) (2023.11.17)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.7.1->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.7.1->-r requirements.txt (line 1)) (3.0.3)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipykernel->jupyterlab==4.0.7->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipykernel->jupyterlab==4.0.7->-r requirements.txt (line 2)) (1.8.12)
# Requirement already satisfied: psutil in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from ipykernel->jupyterlab==4.0.7->-r requirements.txt (line 2)) (5.9.8)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 KB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.7.1->-r requirements.txt (line 1)) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (0.8.4)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.23.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.1/386.1 KB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=22.2.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.0.7->-r requirements.txt (line 2)) (23.2.0)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.0/186.0 KB 6.7 MB/s eta 0:00:00
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 KB 4.4 MB/s eta 0:00:00a 0:00:01
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.1.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 KB 9.0 MB/s eta 0:00:00
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.1->-r requirements.txt (line 10)) (2.2.0)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.0.7->-r requirements.txt (line 2)) (1.16.0)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: pycparser in /home/mle-user/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.0.7->-r requirements.txt (line 2)) (2.21)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 10.5 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, mpmath, kaleido, fastjsonschema, widgetsnbextension, websocket-client, webcolors, uri-template, types-python-dateutil, tomli, tinycss2, terminado, sympy, soupsieve, sniffio, send2trash, scipy, rpds-py, rfc3986-validator, rfc3339-validator, querystring-parser, python-json-logger, pyjwt, pyarrow, psycopg-pool, psycopg-binary, psycopg, protobuf, prometheus-client, plotly, pandocfilters, overrides, oauthlib, mistune, llvmlite, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, importlib-metadata, gunicorn, fqdn, flexparser, flexcache, defusedxml, colorlog, cloudpickle, bleach, babel, async-lru, scikit-learn, referencing, pint, pandas, numba, jupyter-server-terminals, Flask, docker, databricks-cli, botocore, beautifulsoup4, arrow, argon2-cffi-bindings, anyio, seaborn, optuna, mlxtend, mlflow, jsonschema-specifications, isoduration, ipywidgets, autofeat, argon2-cffi, jsonschema, boto3, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.12.0
#     Uninstalling scipy-1.12.0:
#       Successfully uninstalled scipy-1.12.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 19.0.1
#     Uninstalling pyarrow-19.0.1:
#       Successfully uninstalled pyarrow-19.0.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Successfully uninstalled protobuf-5.29.3
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.18.0
#     Uninstalling plotly-5.18.0:
#       Successfully uninstalled plotly-5.18.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: gunicorn
#     Found existing installation: gunicorn 23.0.0
#     Uninstalling gunicorn-23.0.0:
#       Successfully uninstalled gunicorn-23.0.0
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.1
#     Uninstalling cloudpickle-3.1.1:
#       Successfully uninstalled cloudpickle-3.1.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.4.0
#     Uninstalling scikit-learn-1.4.0:
#       Successfully uninstalled scikit-learn-1.4.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.0
#     Uninstalling pandas-2.2.0:
#       Successfully uninstalled pandas-2.2.0
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.0
#     Uninstalling Flask-3.1.0:
#       Successfully uninstalled Flask-3.1.0
#   Attempting uninstall: docker
#     Found existing installation: docker 7.1.0
#     Uninstalling docker-7.1.0:
#       Successfully uninstalled docker-7.1.0
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.27
#     Uninstalling botocore-1.34.27:
#       Successfully uninstalled botocore-1.34.27
#   Attempting uninstall: mlflow
#     Found existing installation: mlflow 2.20.3
#     Uninstalling mlflow-2.20.3:
#       Successfully uninstalled mlflow-2.20.3
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.34.27
#     Uninstalling boto3-1.34.27:
#       Successfully uninstalled boto3-1.34.27
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.11.1 requires botocore<1.34.28,>=1.33.2, but you have botocore 1.34.162 which is incompatible.
# Successfully installed Flask-2.3.3 anyio-4.8.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 autofeat-2.1.2 babel-2.17.0 beautifulsoup4-4.13.3 bleach-6.2.0 boto3-1.34.77 botocore-1.34.162 cloudpickle-2.2.1 colorlog-6.9.0 databricks-cli-0.18.0 defusedxml-0.7.1 docker-6.1.3 fastjsonschema-2.21.1 flexcache-0.3 flexparser-0.4 fqdn-1.5.1 gunicorn-21.2.0 importlib-metadata-6.11.0 ipywidgets-8.1.1 isoduration-20.11.0 json5-0.10.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.0.7 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-3.0.13 kaleido-0.2.1 llvmlite-0.44.0 mistune-3.1.2 mlflow-2.7.1 mlxtend-0.23.0 mpmath-1.3.0 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-shim-0.2.4 numba-0.61.0 oauthlib-3.2.2 optuna-3.4.0 overrides-7.7.0 pandas-2.0.1 pandocfilters-1.5.1 pint-0.24.4 plotly-5.20.0 prometheus-client-0.21.1 protobuf-4.25.6 psycopg-3.1.12 psycopg-binary-3.1.12 psycopg-pool-3.2.6 pyarrow-13.0.0 pyjwt-2.10.1 python-json-logger-3.3.0 querystring-parser-1.2.4 referencing-0.36.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.23.1 scikit-learn-1.3.1 scipy-1.11.3 seaborn-0.13.0 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.6 sympy-1.13.3 terminado-0.18.1 tinycss2-1.4.0 tomli-2.2.1 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.13
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg
import pandas as pd


connection = {"sslmode": "require", "target_session_attrs": "read-write"}
postgres_credentials = {
    "host": "", 
    "port": "",
    "dbname": "",
    "user": "",
    "password": "",
}
assert all([var_value != "" for var_value in list(postgres_credentials.values())])

connection.update(postgres_credentials)

# определим название таблицы, в которой хранятся наши данные.
TABLE_NAME = "users_churn"

# эта конструкция создаёт контекстное управление для соединения с базой данных 
# оператор with гарантирует, что соединение будет корректно закрыто после выполнения всех операций 
# закрыто оно будет даже в случае ошибки, чтобы не допустить "утечку памяти"
with psycopg.connect(**connection) as conn:

# создаёт объект курсора для выполнения запросов к базе данных
# с помощью метода execute() выполняется SQL-запрос для выборки данных из таблицы TABLE_NAME
    with conn.cursor() as cur:
        cur.execute(f"SELECT * FROM {TABLE_NAME}")
                
                # извлекаем все строки, полученные в результате выполнения запроса
        data = cur.fetchall()

                # получает список имён столбцов из объекта курсора
        columns = [col[0] for col in cur.description]

# создаёт объект DataFrame из полученных данных и имён столбцов. 
# это позволяет удобно работать с данными в Python, используя библиотеку Pandas.
df = pd.DataFrame(data, columns=columns)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 13
#       5 connection = {"sslmode": "require", "target_session_attrs": "read-write"}
#       6 postgres_credentials = {
#       7     "host": "",
#       8     "port": "",
#    (...)
#      11     "password": "",
#      12 }
# ---> 13 assert all([var_value != "" for var_value in list(postgres_credentials.values())])
#      15 connection.update(postgres_credentials)
#      17 # определим название таблицы, в которой хранятся наши данные.
#
# AssertionError:

# %%
# задаём название эксперимента и имя запуска для логирования в MLflow
import os

import mlflow

EXPERIMENT_NAME = "churn_fio_denis_putov"
RUN_NAME = "data_check"

# создаём новый эксперимент в MLflow с указанным названием 
# если эксперимент с таким именем уже существует, 
# MLflow возвращает идентификатор существующего эксперимента
mlflow.set_experiment(EXPERIMENT_NAME)  # Если эксперимент существует, он будет активирован
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
experiment_id = experiment.experiment_id  # ваш код здесь

with mlflow.start_run(run_name=RUN_NAME) as run:
    run_id = run.info.run_id # ваш код здесь

    if 'stats' in locals() or 'stats' in globals():
        mlflow.log_metrics(stats)    
    # логируем метрики эксперимента
    # предполагается, что переменная stats содержит словарь с метриками,
    # где ключи — это названия метрик, а значения — числовые значения метрик
    # # ваш код здесь
    # логируем файлы как артефакты эксперимента — 'columns.txt' и 'users_churn.csv'
    mlflow.log_artifact("columns.txt", artifact_path="dataframe")
    mlflow.log_artifact("users_churn.csv", artifact_path="dataframe")


experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
# получаем данные о запуске эксперимента по его уникальному идентификатору
run = mlflow.get_run(run_id)# ваш код здесь


assert run.info.status == "FINISHED", "Запуск не завершился успешно"# проверяем, что статус запуска эксперимента изменён на 'FINISHED'
# это утверждение (assert) можно использовать для автоматической проверки того, 
# что эксперимент был завершён успешно

# удаляем файлы 'columns.txt' и 'users_churn.csv' из файловой системы,
# чтобы очистить рабочую среду после логирования артефактов
for file in ["columns.txt", "users_churn.csv"]:
    if os.path.exists(file):
        os.remove(file)
# Out:
# 2025/03/11 19:35:39 INFO mlflow.tracking.fluent: Experiment with name 'churn_fio_denis_putov' does not exist. Creating a new experiment.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 26
#      20         mlflow.log_metrics(stats)
#      21     # логируем метрики эксперимента
#      22     # предполагается, что переменная stats содержит словарь с метриками,
#      23     # где ключи — это названия метрик, а значения — числовые значения метрик
#      24     # # ваш код здесь
#      25     # логируем файлы как артефакты эксперимента — 'columns.txt' и 'users_churn.csv'
# ---> 26     mlflow.log_artifact("columns.txt", artifact_path="dataframe")
#      27     mlflow.log_artifact("users_churn.csv", artifact_path="dataframe")
#      30 experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
#
# File ~/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages/mlflow/tracking/fluent.py:1179, in log_artifact(local_path, artifact_path, run_id)
#    1149 """
#    1150 Log a local file or directory as an artifact of the currently active run. If no run is
#    1151 active, this method will create a new active run.
#    (...)
#    1176             mlflow.log_artifact(path)
#    1177 """
#    1178 run_id = run_id or _get_or_start_run().info.run_id
# -> 1179 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File ~/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages/mlflow/tracking/client.py:2000, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    1996 if run_id.startswith(TRACE_REQUEST_ID_PREFIX):
#    1997     raise MlflowException(
#    1998         f"Invalid run id: {run_id}. `log_artifact` run id must map to a valid run."
#    1999     )
# -> 2000 self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File ~/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:926, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     924     artifact_repo.log_artifacts(local_path, path_name)
#     925 else:
# --> 926     artifact_repo.log_artifact(local_path, artifact_path)
#
# File ~/mle_projects/mle-dvc/.venv_mle-dvc/lib/python3.10/site-packages/mlflow/store/artifact/local_artifact_repo.py:45, in LocalArtifactRepository.log_artifact(self, local_file, artifact_path)
#      43     mkdir(artifact_dir)
#      44 try:
# ---> 45     shutil.copy2(local_file, os.path.join(artifact_dir, os.path.basename(local_file)))
#      46 except shutil.SameFileError:
#      47     pass
#
# File /usr/lib/python3.10/shutil.py:434, in copy2(src, dst, follow_symlinks)
#     432 if os.path.isdir(dst):
#     433     dst = os.path.join(dst, os.path.basename(src))
# --> 434 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     435 copystat(src, dst, follow_symlinks=follow_symlinks)
#     436 return dst
#
# File /usr/lib/python3.10/shutil.py:254, in copyfile(src, dst, follow_symlinks)
#     252     os.symlink(os.readlink(src), dst)
#     253 else:
# --> 254     with open(src, 'rb') as fsrc:
#     255         try:
#     256             with open(dst, 'wb') as fdst:
#     257                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'columns.txt'
